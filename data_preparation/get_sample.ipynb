# %%
import pandas as pd 
df=pd.read_csv(r"C:\nihal\rough\playpen-paper-2025\SFT\Data\final_data\DPO_dataset_1.csv")
sample_df = df.sample(int(len(df)/70), random_state=42)
sample_df.to_csv(r"C:\nihal\rough\playpen-paper-2025\SFT\Data\final_data\DPO_dataset_1_s.csv",index=False)

# %%
len(sample_df)
# Out:
# 54642
