# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r"C:\nihal\PROJECT\rough\playpen-paper-2025\SFT\Data\final_data\D10001.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df)
# Out:
# 31779
